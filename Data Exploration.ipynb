# %%
print ("Random Data Exploration")
# Out:
# Random Data Exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
train=pd.read_csv("J:/Kaggle - Taxi ride time/train.csv",low_memory=False)

# %%
train
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0        id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1        id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2        id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3        id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4        id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
# 5        id0801584          2  2016-01-30 22:01:40  2016-01-30 22:09:03
# 6        id1813257          1  2016-06-17 22:34:59  2016-06-17 22:40:40
# 7        id1324603          2  2016-05-21 07:54:58  2016-05-21 08:20:49
# 8        id1301050          1  2016-05-27 23:12:23  2016-05-27 23:16:38
# 9        id0012891          2  2016-03-10 21:45:01  2016-03-10 22:05:26
# 10       id1436371          2  2016-05-10 22:08:41  2016-05-10 22:29:55
# 11       id1299289          2  2016-05-15 11:16:11  2016-05-15 11:34:59
# ...

# %%
train.describe()
# Out:
#           vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  1.458644e+06     1.458644e+06      1.458644e+06     1.458644e+06
# mean   1.534950e+00     1.664530e+00     -7.397349e+01     4.075092e+01
# std    4.987772e-01     1.314242e+00      7.090186e-02     3.288119e-02
# min    1.000000e+00     0.000000e+00     -1.219333e+02     3.435970e+01
# 25%    1.000000e+00     1.000000e+00     -7.399187e+01     4.073735e+01
# 50%    2.000000e+00     1.000000e+00     -7.398174e+01     4.075410e+01
# 75%    2.000000e+00     2.000000e+00     -7.396733e+01     4.076836e+01
# max    2.000000e+00     9.000000e+00     -6.133553e+01     5.188108e+01
#
#        dropoff_longitude  dropoff_latitude  trip_duration
# count       1.458644e+06      1.458644e+06   1.458644e+06
# mean       -7.397342e+01      4.075180e+01   9.594923e+02
# std         7.064327e-02      3.589056e-02   5.237432e+03
# min        -1.219333e+02      3.218114e+01   1.000000e+00
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458644 entries, 0 to 1458643
# Data columns (total 11 columns):
# id                    1458644 non-null object
# vendor_id             1458644 non-null int64
# pickup_datetime       1458644 non-null object
# dropoff_datetime      1458644 non-null object
# passenger_count       1458644 non-null int64
# pickup_longitude      1458644 non-null float64
# pickup_latitude       1458644 non-null float64
# dropoff_longitude     1458644 non-null float64
# dropoff_latitude      1458644 non-null float64
# store_and_fwd_flag    1458644 non-null object
# trip_duration         1458644 non-null int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 122.4+ MB

# %%
import math

# %%
train.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2  id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3  id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4  id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.765602                  N            455
# ...

# %%
def haversine(lon1, lat1, lon2, lat2):
    # Convert coordinates to floats.
    lon1, lat1, lon2, lat2 = [float(lon1), float(lat1), float(lon2), float(lat2)]
    # Convert to radians from degrees.
    lon1, lat1, lon2, lat2 = map(math.radians, [lon1, lat1, lon2, lat2])
    # Compute distance.
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a)) 
    km = 6367 * c
    return km

# %%
haversine(train['pickup_longitude'][0],train['pickup_latitude'][0],train['dropoff_longitude'][0],train['dropoff_latitude'][0])
# Out:
# 1.4975799409833876

# %%
for i in range(0,len(train)):
    train_haversineDistance[i]=haversine(train['pickup_longitude'][i],train['pickup_latitude'][i],train['dropoff_longitude'][i],train['dropoff_latitude'][i])

# %% [raw]
# train

# %%
train['haversineInKms']={0}
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-4f7c01af9f89> in <module>()
# ----> 1 train['haversineInKms']={0}
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2427         else:
#    2428             # set column
# -> 2429             self._set_item(key, value)
#    2430
#    2431     def _setitem_slice(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2493
#    2494         self._ensure_valid_index(value)
# -> 2495         value = self._sanitize_column(key, value)
#    2496         NDFrame._set_item(self, key, value)
#    2497
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    2664
#    2665             # turn me into an ndarray
# ...

# %%
len(train)
# Out:
# 1458644

# %%
train_haversineDistance=np.zeros(len(train),dtype='float')

# %%
train_haversineDistance
# Out:
# array([ 1.49757994,  1.80437359,  6.38108964, ...,  7.81969314,
#         1.09187793,  1.13332996])

# %%
plt.plot(train1['haversineInKms'],train1['trip_duration'],'ro')

# %%
plt.show()

# %%
train1=train.assign(haversineInKms = train_haversineDistance)

# %%
train1
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0        id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1        id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2        id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3        id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4        id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
# 5        id0801584          2  2016-01-30 22:01:40  2016-01-30 22:09:03
# 6        id1813257          1  2016-06-17 22:34:59  2016-06-17 22:40:40
# 7        id1324603          2  2016-05-21 07:54:58  2016-05-21 08:20:49
# 8        id1301050          1  2016-05-27 23:12:23  2016-05-27 23:16:38
# 9        id0012891          2  2016-03-10 21:45:01  2016-03-10 22:05:26
# 10       id1436371          2  2016-05-10 22:08:41  2016-05-10 22:29:55
# 11       id1299289          2  2016-05-15 11:16:11  2016-05-15 11:34:59
# ...

# %%
train
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0        id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1        id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2        id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3        id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4        id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
# 5        id0801584          2  2016-01-30 22:01:40  2016-01-30 22:09:03
# 6        id1813257          1  2016-06-17 22:34:59  2016-06-17 22:40:40
# 7        id1324603          2  2016-05-21 07:54:58  2016-05-21 08:20:49
# 8        id1301050          1  2016-05-27 23:12:23  2016-05-27 23:16:38
# 9        id0012891          2  2016-03-10 21:45:01  2016-03-10 22:05:26
# 10       id1436371          2  2016-05-10 22:08:41  2016-05-10 22:29:55
# 11       id1299289          2  2016-05-15 11:16:11  2016-05-15 11:34:59
# ...
